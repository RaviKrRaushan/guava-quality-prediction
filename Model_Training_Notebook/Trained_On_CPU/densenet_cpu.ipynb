# %% [markdown]
# # All imports

# %%
import cv2
import os
import random
from google.colab import drive
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Concatenate, Input, Add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import seaborn as sns
import time
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Drive Set up

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_dirs = {
    'rotten': '/content/drive/MyDrive/data/rotten',
    'mid': '/content/drive/MyDrive/data/mid',
    'fresh': '/content/drive/MyDrive/data/fresh'
}

# %%
output_dirs = {
    'rotten': '/content/drive/MyDrive/data/rotten_frames',
    'mid': '/content/drive/MyDrive/data/mid_frames',
    'fresh': '/content/drive/MyDrive/data/fresh_frames'
}

# %%
for category, out_dir in output_dirs.items():
    os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ## Frame Extraction

# %%
fresh_frames_dir = '/content/drive/MyDrive/data/fresh_frames'
mid_frames_dir = '/content/drive/MyDrive/data/mid_frames'
rotten_frames_dir = '/content/drive/MyDrive/data/rotten_frames'

fresh_images_count = len([file for file in os.listdir(fresh_frames_dir) if file.endswith('.jpg')])
mid_images_count = len([file for file in os.listdir(mid_frames_dir) if file.endswith('.jpg')])
rotten_images_count = len([file for file in os.listdir(rotten_frames_dir) if file.endswith('.jpg')])

print(f"Number of images in fresh_frames: {fresh_images_count}")
print(f"Number of images in mid_frames: {mid_images_count}")
print(f"Number of images in rotten_frames: {rotten_images_count}")
# Out:
# Number of images in fresh_frames: 110
# Number of images in mid_frames: 130
# Number of images in rotten_frames: 60

# %% [markdown]
# ## Data preprocessing

# %%
base_path = "/content/drive/MyDrive/data/augmented"

folders = {
    "fresh": "augmented_fresh_frames",
    "mid": "augmented_mid_frames",
    "rotten": "augmented_rotten_frames"
}

for label, folder in folders.items():
    folder_path = os.path.join(base_path, folder)
    count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"Number of images in {folder}: {count}")
# Out:
# Number of images in augmented_fresh_frames: 1100
# Number of images in augmented_mid_frames: 1300
# Number of images in augmented_rotten_frames: 600

# %%
rotten_dir = os.path.join(base_path, 'augmented_rotten_frames')
mid_dir = os.path.join(base_path, 'augmented_mid_frames')
fresh_dir = os.path.join(base_path, 'augmented_fresh_frames')

# %%
# Class weights (handle imbalance)
total_images = {
    'rotten': 600,
    'mid': 1300,
    'fresh': 1100
}

total = sum(total_images.values())

# 0 - rotten, 1 - mid, 2 - fresh
class_weights = {
    0: int(total / total_images['rotten']),  # rotten
    1: int(total / total_images['mid']),     # mid
    2: int(total / total_images['fresh'])    # fresh
}

print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: 5, 1: 2, 2: 2}

# %%
batch_size = 32
img_size = (224, 224)

datagen = ImageDataGenerator(
    validation_split=0.3,
)
#Training data
train_data = datagen.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)
#Validation data
val_data = datagen.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %% [markdown]
# # Models Training

# %% [markdown]
# ## VGG16

# %%
#RGB to BGR
from tensorflow.keras.applications.vgg16 import preprocess_input

datagen_vgg = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

#Loading training data
train_data_vgg = datagen_vgg.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

#Loading validation data
val_data_vgg = datagen_vgg.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import VGG16

#Loading vgg16
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freezing the base layers
for layer in base_model.layers:
    layer.trainable = False

#Model Building
model_vgg = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
#Compilation
model_vgg.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

#Model summary
model_vgg.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,846,787 (56.64 MB)
#  Trainable params: 132,099 (516.01 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_vgg = ModelCheckpoint(
    "vgg_cpu.h5",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_vgg = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_vgg = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_vgg = time.time()

history_vgg = model_vgg.fit(
    train_data_vgg,
    epochs=50,
    validation_data=val_data_vgg,
    callbacks=[checkpoint_vgg, reduce_lr_vgg, early_stopping_vgg]
)

end_vgg = time.time()
runtime_vgg = end_vgg - start_vgg

print(f"Training Time for VGG16 model: {runtime_vgg:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.3811 - loss: 3.4896
# Epoch 1: val_accuracy improved from -inf to 0.83444, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 593ms/step - accuracy: 0.3834 - loss: 3.4733 - val_accuracy: 0.8344 - val_loss: 0.6327
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.7652 - loss: 1.0370
# Epoch 2: val_accuracy improved from 0.83444 to 0.89222, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 397ms/step - accuracy: 0.7654 - loss: 1.0365 - val_accuracy: 0.8922 - val_loss: 0.4248
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.8104 - loss: 0.7655
# Epoch 3: val_accuracy improved from 0.89222 to 0.90222, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 395ms/step - accuracy: 0.8108 - loss: 0.7637 - val_accuracy: 0.9022 - val_loss: 0.2820
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.8353 - loss: 0.5901
# Epoch 4: val_accuracy improved from 0.90222 to 0.91444, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 398ms/step - accuracy: 0.8355 - loss: 0.5897 - val_accuracy: 0.9144 - val_loss: 0.2478
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.8682 - loss: 0.4372
# Epoch 5: val_accuracy improved from 0.91444 to 0.92222, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 391ms/step - accuracy: 0.8682 - loss: 0.4372 - val_accuracy: 0.9222 - val_loss: 0.2000
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.8804 - loss: 0.3825
# Epoch 6: val_accuracy improved from 0.92222 to 0.92889, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 400ms/step - accuracy: 0.8805 - loss: 0.3822 - val_accuracy: 0.9289 - val_loss: 0.1798
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.8998 - loss: 0.3115
# Epoch 7: val_accuracy did not improve from 0.92889
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 397ms/step - accuracy: 0.8998 - loss: 0.3115 - val_accuracy: 0.9278 - val_loss: 0.1654
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9042 - loss: 0.2682
# Epoch 8: val_accuracy improved from 0.92889 to 0.93111, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 408ms/step - accuracy: 0.9043 - loss: 0.2680 - val_accuracy: 0.9311 - val_loss: 0.1577
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9144 - loss: 0.2328
# Epoch 9: val_accuracy improved from 0.93111 to 0.94667, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 40s 393ms/step - accuracy: 0.9144 - loss: 0.2327 - val_accuracy: 0.9467 - val_loss: 0.1340
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9166 - loss: 0.2271
# Epoch 10: val_accuracy improved from 0.94667 to 0.94889, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 401ms/step - accuracy: 0.9167 - loss: 0.2272 - val_accuracy: 0.9489 - val_loss: 0.1268
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9248 - loss: 0.1968
# Epoch 11: val_accuracy improved from 0.94889 to 0.95111, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 435ms/step - accuracy: 0.9247 - loss: 0.1971 - val_accuracy: 0.9511 - val_loss: 0.1193
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9163 - loss: 0.2026
# Epoch 12: val_accuracy improved from 0.95111 to 0.95222, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 396ms/step - accuracy: 0.9165 - loss: 0.2023 - val_accuracy: 0.9522 - val_loss: 0.1167
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9466 - loss: 0.1442
# Epoch 13: val_accuracy did not improve from 0.95222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 396ms/step - accuracy: 0.9465 - loss: 0.1444 - val_accuracy: 0.9522 - val_loss: 0.1121
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9363 - loss: 0.1533
# Epoch 14: val_accuracy improved from 0.95222 to 0.95667, saving model to best_vgg_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 395ms/step - accuracy: 0.9363 - loss: 0.1535 - val_accuracy: 0.9567 - val_loss: 0.1076
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9428 - loss: 0.1422
# Epoch 15: val_accuracy did not improve from 0.95667
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9792 - loss: 0.0637
# Epoch 36: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 400ms/step - accuracy: 0.9792 - loss: 0.0637 - val_accuracy: 0.9644 - val_loss: 0.0888
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9703 - loss: 0.0671
# Epoch 37: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 375ms/step - accuracy: 0.9703 - loss: 0.0671 - val_accuracy: 0.9622 - val_loss: 0.0868
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9685 - loss: 0.0735
# Epoch 38: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 389ms/step - accuracy: 0.9685 - loss: 0.0734 - val_accuracy: 0.9633 - val_loss: 0.0891
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9717 - loss: 0.0642
# Epoch 39: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 42s 399ms/step - accuracy: 0.9718 - loss: 0.0641 - val_accuracy: 0.9644 - val_loss: 0.0840
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9770 - loss: 0.0510
# Epoch 40: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 398ms/step - accuracy: 0.9771 - loss: 0.0510 - val_accuracy: 0.9656 - val_loss: 0.0834
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9762 - loss: 0.0641
# Epoch 41: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 378ms/step - accuracy: 0.9762 - loss: 0.0641 - val_accuracy: 0.9600 - val_loss: 0.0835
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9718 - loss: 0.0658
# Epoch 42: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 42s 388ms/step - accuracy: 0.9718 - loss: 0.0658 - val_accuracy: 0.9567 - val_loss: 0.0854
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9730 - loss: 0.0612
# Epoch 43: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 42s 399ms/step - accuracy: 0.9730 - loss: 0.0612 - val_accuracy: 0.9600 - val_loss: 0.0840
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9767 - loss: 0.0610
# Epoch 44: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 391ms/step - accuracy: 0.9767 - loss: 0.0610 - val_accuracy: 0.9644 - val_loss: 0.0854
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9776 - loss: 0.0488
# Epoch 45: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 379ms/step - accuracy: 0.9776 - loss: 0.0488 - val_accuracy: 0.9611 - val_loss: 0.0863
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9752 - loss: 0.0526
# Epoch 46: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 385ms/step - accuracy: 0.9752 - loss: 0.0526 - val_accuracy: 0.9633 - val_loss: 0.0824
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9783 - loss: 0.0527
# Epoch 47: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 394ms/step - accuracy: 0.9783 - loss: 0.0527 - val_accuracy: 0.9667 - val_loss: 0.0813
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9821 - loss: 0.0473
# Epoch 48: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 41s 390ms/step - accuracy: 0.9821 - loss: 0.0473 - val_accuracy: 0.9656 - val_loss: 0.0828
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9800 - loss: 0.0465
# Epoch 49: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 375ms/step - accuracy: 0.9799 - loss: 0.0466 - val_accuracy: 0.9633 - val_loss: 0.0809
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9841 - loss: 0.0402
# Epoch 50: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 423ms/step - accuracy: 0.9841 - loss: 0.0403 - val_accuracy: 0.9644 - val_loss: 0.0794
# Training Time for VGG16 model: 1439.94 seconds

# %%
# model_vgg = load_model("vgg_cpu.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss_vgg, accuracy_vgg = model_vgg.evaluate(val_data_vgg)
print(f"Validation Accuracy: {accuracy_vgg:.4f}, Validation Loss: {loss_vgg:.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.9619 - loss: 0.0985
# Validation Accuracy: 0.9678, Validation Loss: 0.0905

# %%
#Plots for VGG16 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_vgg.history['accuracy'], label='Train Accuracy')
plt.plot(history_vgg.history['val_accuracy'], label='Val Accuracy')
plt.title('VGG16 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_vgg.history['loss'], label='Train Loss')
plt.plot(history_vgg.history['val_loss'], label='Val Loss')
plt.title('VGG16 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Cnfusion matrix
#Prediction on validation data
val_pred_vgg = model_vgg.predict(val_data_vgg)
y_pred_vgg = np.argmax(val_pred_vgg, axis=1)

y_true_vgg = val_data_vgg.classes

class_names = list(val_data_vgg.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 320ms/step

# %%
#confusion mat
cm_vgg = confusion_matrix(y_true_vgg, y_pred_vgg)

plt.figure(figsize=(6, 5))
sns.heatmap(cm_vgg, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Vgg16')
plt.show()

# %% [markdown]
# ## MobileNetV2

# %%
from tensorflow.keras.applications.mobilenet import preprocess_input

datagen_mobilenet = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

#Loading training data
train_data_mobilenet = datagen_mobilenet.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

#Loading validation data
val_data_mobilenet = datagen_mobilenet.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
base_model = MobileNetV2(input_shape=(img_size[0], img_size[1], 3), include_top=False, weights='imagenet')
base_model.trainable = False

model_mobilenetv2 = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model_mobilenetv2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model_mobilenetv2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,691 (9.87 MB)
#  Trainable params: 328,707 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_mobilenet = ModelCheckpoint(
    'mobilenet_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_mobilenet = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_mobilenet = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_mobilenetv2 = time.time()

history_mobilenetv2 = model_mobilenetv2.fit(
    train_data_mobilenet,
    epochs=50,
    validation_data=val_data_mobilenet,
    callbacks=[checkpoint_mobilenet, reduce_lr_mobilenet, early_stopping_mobilenet]
)

end_mobilenetv2 = time.time()
runtime_mobilenetv2 = end_mobilenetv2 - start_mobilenetv2

print(f"Training Time for MobileNetV2 model: {runtime_mobilenetv2:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9509 - loss: 0.1207
# Epoch 1: val_accuracy improved from -inf to 0.93667, saving model to best_model_mobilenet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 22s 331ms/step - accuracy: 0.9509 - loss: 0.1208 - val_accuracy: 0.9367 - val_loss: 0.1276
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9488 - loss: 0.1060
# Epoch 2: val_accuracy improved from 0.93667 to 0.95444, saving model to best_model_mobilenet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 22s 329ms/step - accuracy: 0.9489 - loss: 0.1061 - val_accuracy: 0.9544 - val_loss: 0.1012
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9556 - loss: 0.1005
# Epoch 3: val_accuracy improved from 0.95444 to 0.96000, saving model to best_model_mobilenet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.9556 - loss: 0.1008 - val_accuracy: 0.9600 - val_loss: 0.0876
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9643 - loss: 0.0858
# Epoch 4: val_accuracy did not improve from 0.96000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.9644 - loss: 0.0858 - val_accuracy: 0.9589 - val_loss: 0.0842
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9642 - loss: 0.0850
# Epoch 5: val_accuracy did not improve from 0.96000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.9643 - loss: 0.0848 - val_accuracy: 0.9600 - val_loss: 0.0999
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9628 - loss: 0.0860
# Epoch 6: val_accuracy improved from 0.96000 to 0.96222, saving model to best_model_mobilenet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.9628 - loss: 0.0861 - val_accuracy: 0.9622 - val_loss: 0.0884
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9666 - loss: 0.0748
# Epoch 7: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 22s 332ms/step - accuracy: 0.9666 - loss: 0.0749 - val_accuracy: 0.9567 - val_loss: 0.0935
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9736 - loss: 0.0560
# Epoch 8: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.9737 - loss: 0.0559 - val_accuracy: 0.9578 - val_loss: 0.1014
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9681 - loss: 0.0651
# Epoch 9: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 387ms/step - accuracy: 0.9682 - loss: 0.0650 - val_accuracy: 0.9578 - val_loss: 0.0818
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9736 - loss: 0.0617
# Epoch 10: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 380ms/step - accuracy: 0.9736 - loss: 0.0617 - val_accuracy: 0.9622 - val_loss: 0.0884
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9765 - loss: 0.0528
# Epoch 11: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 392ms/step - accuracy: 0.9764 - loss: 0.0529 - val_accuracy: 0.9567 - val_loss: 0.0893
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9797 - loss: 0.0471
# Epoch 12: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s
.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.9698 - loss: 0.0866
# Validation Accuracy: 0.9667, Validation Loss: 0.0963

# %%
#Plots for MobileNetV2 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_mobilenetv2.history['accuracy'], label='Train Accuracy')
plt.plot(history_mobilenetv2.history['val_accuracy'], label='Val Accuracy')
plt.title('MobileNetV2 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_mobilenetv2.history['loss'], label='Train Loss')
plt.plot(history_mobilenetv2.history['val_loss'], label='Val Loss')
plt.title('MobileNetV2 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

#Cnfusion matrix
#Prediction on validation data
val_pred_mobilenetv2 = model_mobilenet.predict(val_data_mobilenet)
y_pred_mobilenetv2 = np.argmax(val_pred_mobilenetv2, axis=1)

y_true_mobilenetv2 = val_data_mobilenet.classes

class_names = list(val_data.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 329ms/step

# %%
#confusion matrix
cm_mobilenetv2 = confusion_matrix(y_true_mobilenetv2, y_pred_mobilenetv2)

plt.figure(figsize=(6, 5))
sns.heatmap(cm_mobilenetv2, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - MobileNetV2")
plt.show()

# %% [markdown]
# ## DenseNet201

# %%
#Scaled values using preprocess_input
from tensorflow.keras.applications.densenet import preprocess_input

datagen_preprocessed = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

#Training data
train_data_preprocessed = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

#Validation data
val_data_preprocessed = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import DenseNet201

#Loading DenseNet201
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#Building Model
model_densenet = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#Compilation
model_densenet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Model summary
model_densenet.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet201 (Functional)        │ (None, 7, 7, 1920)     │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       491,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,814,531 (71.77 MB)
#  Trainable params: 492,547 (1.88 MB)
#  Non-trainable params: 18,321,984 (69.89 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_densenet = ModelCheckpoint(
    'densenet_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_densenet = time.time()

history_densenet = model_densenet.fit(
    train_data_preprocessed,
    epochs=50,
    validation_data=val_data_preprocessed,
    callbacks=[checkpoint_densenet, reduce_lr, early_stopping]
)

end_densenet = time.time()
runtime_densenet = end_densenet - start_densenet

print(f"Training Time for DenseNet201 model: {runtime_densenet:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7514 - loss: 0.7081
# Epoch 1: val_accuracy improved from -inf to 0.94556, saving model to densenet_cpu.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1394s 21s/step - accuracy: 0.7529 - loss: 0.7037 - val_accuracy: 0.9456 - val_loss: 0.1468 - learning_rate: 0.0010
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9435 - loss: 0.1599
# Epoch 2: val_accuracy improved from 0.94556 to 0.95444, saving model to densenet_cpu.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 928s 14s/step - accuracy: 0.9434 - loss: 0.1599 - val_accuracy: 0.9544 - val_loss: 0.1178 - learning_rate: 0.0010
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9489 - loss: 0.1233
# Epoch 3: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 960s 15s/step - accuracy: 0.9488 - loss: 0.1234 - val_accuracy: 0.9533 - val_loss: 0.1030 - learning_rate: 0.0010
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9557 - loss: 0.1102
# Epoch 4: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 916s 14s/step - accuracy: 0.9557 - loss: 0.1101 - val_accuracy: 0.9533 - val_loss: 0.0984 - learning_rate: 0.0010
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9487 - loss: 0.1220
# Epoch 5: val_accuracy improved from 0.95444 to 0.95667, saving model to densenet_cpu.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 982s 15s/step - accuracy: 0.9487 - loss: 0.1219 - val_accuracy: 0.9567 - val_loss: 0.0874 - learning_rate: 0.0010
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9652 - loss: 0.0940
# Epoch 6: val_accuracy did not improve from 0.95667
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 982s 15s/step - accuracy: 0.9651 - loss: 0.0943 - val_accuracy: 0.9556 - val_loss: 0.1060 - learning_rate: 0.0010
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9539 - loss: 0.0962
# Epoch 7: val_accuracy improved from 0.95667 to 0.96000, saving model to densenet_cpu.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 973s 15s/step - accuracy: 0.9539 - loss: 0.0962 - val_accuracy: 0.9600 - val_loss: 0.0868 - learning_rate: 0.0010
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9569 - loss: 0.0793
# Epoch 8: val_accuracy did not improve from 0.96000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 946s 14s/step - accuracy: 0.9570 - loss: 0.0793 - val_accuracy: 0.9578 - val_loss: 0.0759 - learning_rate: 0.0010
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9605 - loss: 0.0863
# Epoch 9: val_accuracy improved from 0.96000 to 0.96222, saving model to densenet_cpu.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 936s 14s/step - accuracy: 0.9605 - loss: 0.0862 - val_accuracy: 0.9622 - val_loss: 0.0748 - learning_rate: 0.0010
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9715 - loss: 0.0706
# Epoch 10: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 947s 14s/step - accuracy: 0.9714 - loss: 0.0708 - val_accuracy: 0.9556 - val_loss: 0.0887 - learning_rate: 0.0010
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9690 - loss: 0.0740
# Epoch 11: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 957s 15s/step - accuracy: 0.9690 - loss: 0.0739 - val_accuracy: 0.9600 - val_loss: 0.0829 - learning_rate: 0.0010
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9697 - loss: 0.0650
# Epoch 12: val_accuracy did not improve from 0.96222
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 957s 15s/step - accuracy: 0.9697 - loss: 0.0650 - val_accuracy: 0.9611 - val_loss: 0.0862 - learning_rate: 0.0010
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9730 - loss: 0.0575
# Epoch 13: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 981s 15s/step - accuracy: 0.9731 - loss: 0.0574 - val_accuracy: 0.9622 - val_loss: 0.0787 - learning_rate: 2.0000e-04
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9814 - loss: 0.0489
# Epoch 14: val_accuracy improved from 0.96222 to 0.96333, saving model to densenet_cpu.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 942s 14s/step - accuracy: 0.9814 - loss: 0.0488 - val_accuracy: 0.9633 - val_loss: 0.0762 - learning_rate: 2.0000e-04
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9845 - loss: 0.0409
# Epoch 15: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 989s 15s/step - accuracy: 0.9844 - loss: 0.0409 - val_accuracy: 0.9611 - val_loss: 0.0771 - learning_rate: 2.0000e-04
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9835 - loss: 0.0368
# Epoch 16: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 942s 14s/step - accuracy: 0.9835 - loss: 0.0369 - val_accuracy: 0.9589 - val_loss: 0.0862 - learning_rate: 2.0000e-04
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9789 - loss: 0.0430
# Epoch 17: val_accuracy did not improve from 0.96333
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 944s 14s/step - accuracy: 0.9789 - loss: 0.0431 - val_accuracy: 0.9600 - val_loss: 0.0765 - learning_rate: 2.0000e-04
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9815 - loss: 0.0393
# Epoch 18: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 995s 15s/step - accuracy: 0.9815 - loss: 0.0393 - val_accuracy: 0.9600 - val_loss: 0.0773 - learning_rate: 4.0000e-05
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9782 - loss: 0.0397
# Epoch 19: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 945s 14s/step - accuracy: 0.9783 - loss: 0.0397 - val_accuracy: 0.9611 - val_loss: 0.0770 - learning_rate: 4.0000e-05
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9846 - loss: 0.0365
# Epoch 20: val_accuracy did not improve from 0.96333
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 941s 14s/step - accuracy: 0.9847 - loss: 0.0364 - val_accuracy: 0.9622 - val_loss: 0.0785 - learning_rate: 4.0000e-05
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9876 - loss: 0.0391
# Epoch 21: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 945s 14s/step - accuracy: 0.9876 - loss: 0.0391 - val_accuracy: 0.9600 - val_loss: 0.0778 - learning_rate: 8.0000e-06
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9873 - loss: 0.0304
# Epoch 22: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 932s 14s/step - accuracy: 0.9872 - loss: 0.0306 - val_accuracy: 0.9600 - val_loss: 0.0776 - learning_rate: 8.0000e-06
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9840 - loss: 0.0433
# Epoch 23: val_accuracy did not improve from 0.96333
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 974s 15s/step - accuracy: 0.9840 - loss: 0.0433 - val_accuracy: 0.9600 - val_loss: 0.0773 - learning_rate: 8.0000e-06
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9812 - loss: 0.0436
# Epoch 24: val_accuracy did not improve from 0.96333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 936s 14s/step - accuracy: 0.9812 - loss: 0.0435 - val_accuracy: 0.9600 - val_loss: 0.0773 - learning_rate: 1.6000e-06
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Training Time for DenseNet201 model: 23347.67 seconds

# %%
# model_densenet = load_model('densenet_cpu.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss_densenet, accuracy_densenet = model_densenet.evaluate(val_data_preprocessed)
print(f"Validation Accuracy: {accuracy_densenet:.4f}, Validation Loss: {loss_densenet:.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 279s 10s/step - accuracy: 0.9539 - loss: 0.0816
# Validation Accuracy: 0.9633, Validation Loss: 0.0762

# %%
#Plots for DenseNet201 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_densenet.history['accuracy'], label='Train Accuracy')
plt.plot(history_densenet.history['val_accuracy'], label='Val Accuracy')
plt.title('DenseNet201 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_densenet.history['loss'], label='Train Loss')
plt.plot(history_densenet.history['val_loss'], label='Val Loss')
plt.title('DenseNet201 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Cnfusion matrix
#Prediction on validation data
val_pred_densenet = model_densenet.predict(val_data_preprocessed)
y_pred_densenet = np.argmax(val_pred_densenet, axis=1)

y_true_densenet = val_data_preprocessed.classes

class_names = list(val_data_preprocessed.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 301s 10s/step

# %%
#confusion mat
cm = confusion_matrix(y_true_densenet, y_pred_densenet)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - DenseNet201')
plt.show()

# %% [markdown]
# ## InceptionV3

# %%
from tensorflow.keras.applications.inception_v3 import preprocess_input

datagen_preprocessed = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

# Load training data using datagen_preprocessed
train_data_inception = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Load validation data using datagen_preprocessed
val_data_inception = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import InceptionV3

#Loading InceptionV3
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#Model
model_inception = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Compile
model_inception.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
model_inception.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,328,099 (85.17 MB)
#  Trainable params: 525,315 (2.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_inception = ModelCheckpoint(
    'inception_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_inception = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_inception = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_inception = time.time()

history_inception = model_inception.fit(
    train_data_inception,
    epochs=50,
    validation_data=val_data_inception,
    callbacks=[checkpoint_inception, reduce_lr_inception, early_stopping_inception]
)

end_inception = time.time()
runtime_inception = end_inception - start_inception

print(f"Training Time for InceptionV3 model: {runtime_inception:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.6315 - loss: 0.8844
# Epoch 1: val_accuracy improved from -inf to 0.87333, saving model to best_model_inception.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 72s 778ms/step - accuracy: 0.6332 - loss: 0.8808 - val_accuracy: 0.8733 - val_loss: 0.3460
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8732 - loss: 0.3778
# Epoch 2: val_accuracy improved from 0.87333 to 0.90444, saving model to best_model_inception.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 459ms/step - accuracy: 0.8733 - loss: 0.3773 - val_accuracy: 0.9044 - val_loss: 0.2885
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9149 - loss: 0.2732
# Epoch 3: val_accuracy improved from 0.90444 to 0.91000, saving model to best_model_inception.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 41s 456ms/step - accuracy: 0.9147 - loss: 0.2734 - val_accuracy: 0.9100 - val_loss: 0.2592
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9882 - loss: 0.0395
# Epoch 40: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 456ms/step - accuracy: 0.9882 - loss: 0.0395 - val_accuracy: 0.9489 - val_loss: 0.1186
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9862 - loss: 0.0431
# Epoch 41: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 32s 484ms/step - accuracy: 0.9862 - loss: 0.0431 - val_accuracy: 0.9522 - val_loss: 0.1178
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9905 - loss: 0.0343
# Epoch 42: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 449ms/step - accuracy: 0.9904 - loss: 0.0344 - val_accuracy: 0.9489 - val_loss: 0.1262
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9831 - loss: 0.0403
# Epoch 43: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 455ms/step - accuracy: 0.9831 - loss: 0.0403 - val_accuracy: 0.9522 - val_loss: 0.1211
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9902 - loss: 0.0342
# Epoch 44: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 454ms/step - accuracy: 0.9902 - loss: 0.0342 - val_accuracy: 0.9489 - val_loss: 0.1182
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9961 - loss: 0.0291
# Epoch 45: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 456ms/step - accuracy: 0.9961 - loss: 0.0292 - val_accuracy: 0.9500 - val_loss: 0.1173
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9889 - loss: 0.0325
# Epoch 46: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 455ms/step - accuracy: 0.9889 - loss: 0.0325 - val_accuracy: 0.9489 - val_loss: 0.1258
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9919 - loss: 0.0349
# Epoch 47: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 449ms/step - accuracy: 0.9919 - loss: 0.0349 - val_accuracy: 0.9500 - val_loss: 0.1202
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9941 - loss: 0.0295
# Epoch 48: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 31s 478ms/step - accuracy: 0.9940 - loss: 0.0295 - val_accuracy: 0.9467 - val_loss: 0.1268
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9910 - loss: 0.0307
# Epoch 49: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 31s 471ms/step - accuracy: 0.9910 - loss: 0.0307 - val_accuracy: 0.9444 - val_loss: 0.1234
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9919 - loss: 0.0258
# Epoch 50: val_accuracy did not improve from 0.95556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 39s 436ms/step - accuracy: 0.9919 - loss: 0.0259 - val_accuracy: 0.9522 - val_loss: 0.1190
# Training Time for InceptionV3 model: 1600.73 seconds

# %%
model_inception = load_model("inception_cpu.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss_inception, accuracy_inception = model_inception.evaluate(val_data_inception)
print(f"Validation Accuracy: {accuracy_inception:.4f}, Validation Loss: {loss_inception:.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - accuracy: 0.9501 - loss: 0.1212
# Validation Accuracy: 0.9556, Validation Loss: 0.1194

# %%
#Plots for InceptionV3 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_inception.history['accuracy'], label='Train Accuracy')
plt.plot(history_inception.history['val_accuracy'], label='Val Accuracy')
plt.title('InceptionV3 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_inception.history['loss'], label='Train Loss')
plt.plot(history_inception.history['val_loss'], label='Val Loss')
plt.title('InceptionV3 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Cnfusion matrix
#Prediction on validation data
val_pred_inception = model_inception.predict(val_data_inception)
y_pred_inception = np.argmax(val_pred_inception, axis=1)

y_true_inception = val_data_inception.classes

class_names = list(val_data_inception.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 493ms/step

# %%
cm_inception = confusion_matrix(y_true_inception, y_pred_inception)
#show cm
plt.figure(figsize=(6, 5))
sns.heatmap(cm_inception, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - InceptionV3')
plt.show()

# %% [markdown]
# ## EfficientNetB0

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input

datagen_preprocessed = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

#Training data
train_data_efficientnet = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

#Validation data
val_data_efficientnet = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0

#Loading EfficientNetB0
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#Model Building
model_efficientnet = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
#compilation
model_efficientnet.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

#Model summary
model_efficientnet.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,378,278 (16.70 MB)
#  Trainable params: 328,707 (1.25 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_efficientnet = ModelCheckpoint(
    'efficientnet_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_efficientnet = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_efficientnet = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_efficientnet = time.time()

history_efficientnet = model_efficientnet.fit(
    train_data_efficientnet,
    epochs=50,
    validation_data=val_data_efficientnet,
    callbacks=[checkpoint_efficientnet, reduce_lr_efficientnet, early_stopping_efficientnet]
)

end_efficientnet = time.time()
runtime_efficientnet = end_efficientnet - start_efficientnet

print(f"Training Time for EfficientNetB0 model: {runtime_efficientnet:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.8030 - loss: 0.4797
# Epoch 1: val_accuracy improved from -inf to 0.94333, saving model to best_model_efficientnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 74s 752ms/step - accuracy: 0.8042 - loss: 0.4772 - val_accuracy: 0.9433 - val_loss: 0.1305
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9377 - loss: 0.1553
# Epoch 2: val_accuracy improved from 0.94333 to 0.96111, saving model to best_model_efficientnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 421ms/step - accuracy: 0.9377 - loss: 0.1553 - val_accuracy: 0.9611 - val_loss: 0.1053
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9514 - loss: 0.1177
# Epoch 3: val_accuracy did not improve from 0.96111
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 411ms/step - accuracy: 0.9514 - loss: 0.1178 - val_accuracy: 0.9611 - val_loss: 0.1148
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9525 - loss: 0.1186
# Epoch 4: val_accuracy improved from 0.96111 to 0.96222, saving model to best_model_efficientnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 390ms/step - accuracy: 0.9524 - loss: 0.1186 - val_accuracy: 0.9622 - val_loss: 0.0974
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9574 - loss: 0.1108
# Epoch 5: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 42s 404ms/step - accuracy: 0.9574 - loss: 0.1109 - val_accuracy: 0.9511 - val_loss: 0.0920
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9537 - loss: 0.1040
# Epoch 6: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 411ms/step - accuracy: 0.9538 - loss: 0.1040 - val_accuracy: 0.9589 - val_loss: 0.0838
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9651 - loss: 0.0907
# Epoch 7: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 401ms/step - accuracy: 0.9650 - loss: 0.0908 - val_accuracy: 0.9544 - val_loss: 0.0872
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9703 - loss: 0.0760
# Epoch 8: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 411ms/step - accuracy: 0.9702 - loss: 0.0761 - val_accuracy: 0.9622 - val_loss: 0.1054
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9663 - loss: 0.0894
# Epoch 9: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 397ms/step - accuracy: 0.9663 - loss: 0.0893 - val_accuracy: 0.9622 - val_loss: 0.0755
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9595 - loss: 0.0781
# Epoch 10: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 402ms/step - accuracy: 0.9595 - loss: 0.0782 - val_accuracy: 0.9589 - val_loss: 0.0773
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9613 - loss: 0.0773
# Epoch 11: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 435ms/step - accuracy: 0.9613 - loss: 0.0773 - val_accuracy: 0.9600 - val_loss: 0.0741
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9559 - loss: 0.0956
# Epoch 12: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 388ms/step - accuracy: 0.9559 - loss: 0.0955 - val_accuracy: 0.9622 - val_loss: 0.1018
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9646 - loss: 0.0850
# Epoch 13: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 387ms/step - accuracy: 0.9646 - loss: 0.0850 - val_accuracy: 0.9622 - val_loss: 0.0715
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9720 - loss: 0.0657
# Epoch 14: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 439ms/step - accuracy: 0.9720 - loss: 0.0657 - val_accuracy: 0.9589 - val_loss: 0.0725
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9712 - loss: 0.0670
# Epoch 15: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 433ms/step - accuracy: 0.9711 - loss: 0.0671 - val_accuracy: 0.9578 - val_loss: 0.0845
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9623 - loss: 0.0814
# Epoch 16: val_accuracy did not improve from 0.96222
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9716 - loss: 0.0654
# Epoch 37: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 414ms/step - accuracy: 0.9715 - loss: 0.0654 - val_accuracy: 0.9622 - val_loss: 0.0639
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9799 - loss: 0.0488
# Epoch 38: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 410ms/step - accuracy: 0.9798 - loss: 0.0490 - val_accuracy: 0.9578 - val_loss: 0.0978
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9717 - loss: 0.0529
# Epoch 39: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 394ms/step - accuracy: 0.9717 - loss: 0.0530 - val_accuracy: 0.9622 - val_loss: 0.0678
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9790 - loss: 0.0516
# Epoch 40: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 426ms/step - accuracy: 0.9789 - loss: 0.0517 - val_accuracy: 0.9600 - val_loss: 0.0710
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9733 - loss: 0.0505
# Epoch 41: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 433ms/step - accuracy: 0.9733 - loss: 0.0505 - val_accuracy: 0.9611 - val_loss: 0.0843
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9689 - loss: 0.0558
# Epoch 42: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 38s 394ms/step - accuracy: 0.9690 - loss: 0.0557 - val_accuracy: 0.9644 - val_loss: 0.0788
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9787 - loss: 0.0486
# Epoch 43: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 436ms/step - accuracy: 0.9787 - loss: 0.0486 - val_accuracy: 0.9578 - val_loss: 0.0728
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9786 - loss: 0.0423
# Epoch 44: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 402ms/step - accuracy: 0.9786 - loss: 0.0423 - val_accuracy: 0.9622 - val_loss: 0.0759
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9724 - loss: 0.0507
# Epoch 45: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9724 - loss: 0.0506 - val_accuracy: 0.9611 - val_loss: 0.0786
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9780 - loss: 0.0468
# Epoch 46: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 431ms/step - accuracy: 0.9780 - loss: 0.0468 - val_accuracy: 0.9644 - val_loss: 0.0856
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9755 - loss: 0.0448
# Epoch 47: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 396ms/step - accuracy: 0.9755 - loss: 0.0449 - val_accuracy: 0.9600 - val_loss: 0.0744
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9838 - loss: 0.0446
# Epoch 48: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9838 - loss: 0.0446 - val_accuracy: 0.9578 - val_loss: 0.0783
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9774 - loss: 0.0497
# Epoch 49: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 419ms/step - accuracy: 0.9774 - loss: 0.0496 - val_accuracy: 0.9633 - val_loss: 0.0749
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9753 - loss: 0.0453
# Epoch 50: val_accuracy did not improve from 0.96778
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 39s 396ms/step - accuracy: 0.9753 - loss: 0.0454 - val_accuracy: 0.9600 - val_loss: 0.0750
# Training Time for EfficientNetB0 model: 1472.03 seconds

# %%
# model_efficientnet = load_model("efficientnet_cpu.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss_efficientnet, accuracy_efficientnet = model_efficientnet.evaluate(val_data_efficientnet)
print(f"Validation Accuracy: {accuracy_efficientnet:.8f}, Validation Loss: {loss_efficientnet:.8f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - accuracy: 0.9527 - loss: 0.1289
# Validation Accuracy: 0.92333335, Validation Loss: 0.21164703

# %%
#Plots for EfficientNetB0 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_efficientnet.history['accuracy'], label='Train Accuracy')
plt.plot(history_efficientnet.history['val_accuracy'], label='Val Accuracy')
plt.title('EfficientNetB0 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_efficientnet.history['loss'], label='Train Loss')
plt.plot(history_efficientnet.history['val_loss'], label='Val Loss')
plt.title('EfficientNetB0 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Cnfusion matrix
#Prediction on validation data
val_pred_efficientb0 = model_efficientnet.predict(val_data_efficientnet)
y_pred_efficientb0 = np.argmax(val_pred_efficientb0, axis=1)

y_true_efficientb0 = val_data_efficientnet.classes

class_names = list(val_data_efficientnet.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 514ms/step

# %%
cm_efficientb0 = confusion_matrix(y_true_efficientb0, y_pred_efficientb0)
#show cm
plt.figure(figsize=(6, 5))
sns.heatmap(cm_efficientb0, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - EfficientNetB0')
plt.show()

# %% [markdown]
# ## NASNetMobile

# %%
from tensorflow.keras.applications.nasnet  import preprocess_input

datagen_nasnet = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

#Training data
train_data_nasnet = datagen_nasnet.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

#Validation data
val_data_nasnet = datagen_nasnet.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import NASNetMobile

#Loading NASNetMobile
base_model = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#Model Building
model_nasnet = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
#Compilation
model_nasnet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Summary
model_nasnet.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ nasnet_mobile (Functional)      │ (None, 7, 7, 1056)     │     4,269,716 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1056)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       270,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,541,079 (17.32 MB)
#  Trainable params: 271,363 (1.04 MB)
#  Non-trainable params: 4,269,716 (16.29 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_nasnet = ModelCheckpoint(
    'nasnet_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_nasnet = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_nasnet = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_nasnet = time.time()

history_nasnet = model_nasnet.fit(
    train_data_nasnet,
    epochs=50,
    validation_data=val_data_nasnet,
    callbacks=[checkpoint_nasnet, reduce_lr_nasnet, early_stopping_nasnet]
)

end_nasnet = time.time()
runtime_nasnet = end_nasnet - start_nasnet

print(f"Training Time for NASNetMobile model: {runtime_nasnet:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7738 - loss: 0.5288
# Epoch 1: val_accuracy improved from -inf to 0.91111, saving model to best_model_nasnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.7749 - loss: 0.5268 - val_accuracy: 0.9111 - val_loss: 0.2310
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9152 - loss: 0.2308
# Epoch 2: val_accuracy improved from 0.91111 to 0.93111, saving model to best_model_nasnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 457ms/step - accuracy: 0.9153 - loss: 0.2306 - val_accuracy: 0.9311 - val_loss: 0.1757
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9185 - loss: 0.1980
# Epoch 3: val_accuracy improved from 0.93111 to 0.93333, saving model to best_model_nasnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 436ms/step - accuracy: 0.9186 - loss: 0.1981 - val_accuracy: 0.9333 - val_loss: 0.1811
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9252 - loss: 0.1757
# Epoch 4: val_accuracy did not improve from 0.93333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 434ms/step - accuracy: 0.9252 - loss: 0.1756 - val_accuracy: 0.9211 - val_loss: 0.1955
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9386 - loss: 0.1658
# Epoch 5: val_accuracy improved from 0.93333 to 0.94111, saving model to best_model_nasnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 457ms/step - accuracy: 0.9387 - loss: 0.1655 - val_accuracy: 0.9411 - val_loss: 0.1516
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9521 - loss: 0.1145
# Epoch 6: val_accuracy improved from 0.94111 to 0.95111, saving model to best_model_nasnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 31s 478ms/step - accuracy: 0.9520 - loss: 0.1147 - val_accuracy: 0.9511 - val_loss: 0.1257
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9553 - loss: 0.1130
# Epoch 7: val_accuracy did not improve from 0.95111
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 428ms/step - accuracy: 0.9552 - loss: 0.1131 - val_accuracy: 0.9356 - val_loss: 0.1325
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9553 - loss: 0.1133
# Epoch 8: val_accuracy improved from 0.95111 to 0.95333, saving model to best_model_nasnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 441ms/step - accuracy: 0.9553 - loss: 0.1133 - val_accuracy: 0.9533 - val_loss: 0.1248
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9615 - loss: 0.1004
# Epoch 9: val_accuracy did not improve from 0.95333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 432ms/step - accuracy: 0.9614 - loss: 0.1006 - val_accuracy: 0.9367 - val_loss: 0.1676
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9604 - loss: 0.1030
# Epoch 10: val_accuracy did not improve from 0.95333
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9604 - loss: 0.1031 - val_accuracy: 0.9511 - val_loss: 0.1111
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 442ms/step - accuracy: 0.9943 - loss: 0.0198 - val_accuracy: 0.9556 - val_loss: 0.1575
# Training Time for NASNetMobile model: 1540.09 seconds

# %%
# model_nasnet = load_model("nasnet_cpu.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss_nasnet, accuracy_nasnet = model_nasnet.evaluate(val_data_nasnet)
print(f"Validation Accuracy: {accuracy_nasnet:.4f}, Validation Loss: {loss_nasnet:.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.9559 - loss: 0.1191
# Validation Accuracy: 0.9578, Validation Loss: 0.1191

# %%
#Plots for NASNetMobile Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_nasnet.history['accuracy'], label='Train Accuracy')
plt.plot(history_nasnet.history['val_accuracy'], label='Val Accuracy')
plt.title('NASNetMobile - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_nasnet.history['loss'], label='Train Loss')
plt.plot(history_nasnet.history['val_loss'], label='Val Loss')
plt.title('NASNetMobile - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Cnfusion matrix
#Prediction on validation data
val_pred_nasnet = model_nasnet.predict(val_data_nasnet)
y_pred_nasnet = np.argmax(val_pred_nasnet, axis=1)

y_true_nasnet = val_data_nasnet.classes

class_names = list(val_data_nasnet.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 847ms/step

# %%
cm_nasnet = confusion_matrix(y_true_nasnet, y_pred_nasnet)
#show cm
plt.figure(figsize=(6, 5))
sns.heatmap(cm_nasnet, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - NASNetMobile')
plt.show()

# %% [markdown]
# ## ResNet50

# %%
#Scaling values using preprocess_input
from tensorflow.keras.applications.resnet50 import preprocess_input

batch_size = 32
img_size = (224, 224)

datagen_preprocessed = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

# Load training data using datagen_preprocessed
train_data_resnet = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Load validation data using datagen_preprocessed
val_data_resnet = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import ResNet50

#Loading Resnet50
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#model building
model_resnet = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#Compilation
model_resnet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Model summary
model_resnet.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,113,027 (91.98 MB)
#  Trainable params: 525,315 (2.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_resnet = ModelCheckpoint(
    'resnet_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_resnet = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_resnet = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_resnet = time.time()

history_resnet = model_resnet.fit(
    train_data_resnet,
    epochs=50,
    validation_data=val_data_resnet,
    callbacks=[checkpoint_resnet, reduce_lr_resnet, early_stopping_resnet]
)

end_resnet = time.time()
runtime_resnet = end_resnet - start_resnet

print(f"Training Time for ResNet50 model: {runtime_resnet:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.7594 - loss: 0.7465
# Epoch 1: val_accuracy improved from -inf to 0.92444, saving model to best_model_resnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 48s 533ms/step - accuracy: 0.7609 - loss: 0.7415 - val_accuracy: 0.9244 - val_loss: 0.1747
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9238 - loss: 0.1858
# Epoch 2: val_accuracy improved from 0.92444 to 0.93889, saving model to best_model_resnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 381ms/step - accuracy: 0.9239 - loss: 0.1856 - val_accuracy: 0.9389 - val_loss: 0.1361
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9323 - loss: 0.1510
# Epoch 3: val_accuracy improved from 0.93889 to 0.94111, saving model to best_model_resnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 31s 470ms/step - accuracy: 0.9324 - loss: 0.1508 - val_accuracy: 0.9411 - val_loss: 0.1540
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9379 - loss: 0.1716
# Epoch 4: val_accuracy improved from 0.94111 to 0.95444, saving model to best_model_resnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 38s 573ms/step - accuracy: 0.9381 - loss: 0.1710 - val_accuracy: 0.9544 - val_loss: 0.1058
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9529 - loss: 0.0967
# Epoch 5: val_accuracy improved from 0.95444 to 0.95667, saving model to best_model_resnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s
val_accuracy did not improve from 0.96556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 23s 349ms/step - accuracy: 0.9869 - loss: 0.0274 - val_accuracy: 0.9622 - val_loss: 0.1362
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9812 - loss: 0.0395
# Epoch 45: val_accuracy did not improve from 0.96556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 41s 350ms/step - accuracy: 0.9813 - loss: 0.0394 - val_accuracy: 0.9633 - val_loss: 0.1033
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9886 - loss: 0.0284
# Epoch 46: val_accuracy did not improve from 0.96556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 23s 352ms/step - accuracy: 0.9886 - loss: 0.0284 - val_accuracy: 0.9656 - val_loss: 0.0915
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9882 - loss: 0.0264
# Epoch 47: val_accuracy did not improve from 0.96556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 41s 359ms/step - accuracy: 0.9882 - loss: 0.0265 - val_accuracy: 0.9611 - val_loss: 0.1194
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9894 - loss: 0.0304
# Epoch 48: val_accuracy did not improve from 0.96556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 399ms/step - accuracy: 0.9894 - loss: 0.0305 - val_accuracy: 0.9656 - val_loss: 0.1130
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9917 - loss: 0.0239
# Epoch 49: val_accuracy improved from 0.96556 to 0.96667, saving model to best_model_resnet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 24s 367ms/step - accuracy: 0.9917 - loss: 0.0240 - val_accuracy: 0.9667 - val_loss: 0.1050
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9865 - loss: 0.0406
# Epoch 50: val_accuracy did not improve from 0.96667
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 23s 351ms/step - accuracy: 0.9865 - loss: 0.0405 - val_accuracy: 0.9656 - val_loss: 0.1094
# Training Time for ResNet50 model: 1379.02 seconds

# %%
# model_resnet = load_model("resnet_cpu.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loss_resnet, accuracy_resnet = model_resnet.evaluate(val_data_resnet)
print(f"Validation Accuracy: {accuracy_resnet:.4f}, Validation Loss: {loss_resnet:.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 308ms/step - accuracy: 0.9539 - loss: 0.1388
# Validation Accuracy: 0.9667, Validation Loss: 0.1050

# %%
#Plots for ResNet50 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_resnet.history['accuracy'], label='Train Accuracy')
plt.plot(history_resnet.history['val_accuracy'], label='Val Accuracy')
plt.title('ResNet50 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_resnet.history['loss'], label='Train Loss')
plt.plot(history_resnet.history['val_loss'], label='Val Loss')
plt.title('ResNet50 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Prediction on validation data
val_pred_resnet = model_resnet.predict(val_data_resnet)
y_pred_resnet = np.argmax(val_pred_resnet, axis=1)

y_true_resnet = val_data_resnet.classes

class_names = list(val_data_resnet.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 357ms/step

# %%
#Confusion matrix
cm_resnet = confusion_matrix(y_true_resnet, y_pred_resnet)

plt.figure(figsize=(6, 5))
sns.heatmap(cm_resnet, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - ResNet50")
plt.show()

# %% [markdown]
# ## ResNet101

# %%
#Loading ResNet101
base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#Model Building
model_resnet101 = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8e4509256a5f> in <cell line: 0>()
#       1 #Loading ResNet101
# ----> 2 base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#       3 base_model.trainable = False
#       4
#       5 #Model Building
#
# NameError: name 'ResNet101' is not defined

# %%
#Compilation
model_resnet101.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Summary
model_resnet101.summary()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_resnet101 = ModelCheckpoint(
    'resnet101_cpu.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_resnet101 = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_resnet101 = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_resnet101 = time.time()

history_resnet101 = model_resnet101.fit(
    train_data_resnet,
    epochs=50,
    validation_data=val_data_resnet,
    callbacks=[checkpoint_resnet101, reduce_lr_resnet101, early_stopping_resnet101]
)

end_resnet101 = time.time()
runtime_resnet101 = end_resnet101 - start_resnet101

print(f"Training Time for ResNet101 model: {runtime_resnet101:.2f} seconds")

# %%
# model_resnet101 = load_model("resnet101_cpu.h5")

# %%
loss_resnet101, accuracy_resnet101 = model_resnet101.evaluate(val_data_resnet)
print(f"Validation Accuracy: {accuracy_resnet101:.4f}, Validation Loss: {loss_resnet101:.4f}")

# %%
#Plots for ResNet101 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_resnet101.history['accuracy'], label='Train Accuracy')
plt.plot(history_resnet101.history['val_accuracy'], label='Val Accuracy')
plt.title('ResNet101 - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_resnet101.history['loss'], label='Train Loss')
plt.plot(history_resnet101.history['val_loss'], label='Val Loss')
plt.title('ResNet101 - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Prediction on validation data
val_pred_resnet101 = model_resnet.predict(val_data_resnet)
y_pred_resnet101 = np.argmax(val_pred_resnet101, axis=1)

y_true_resnet101 = val_data_resnet.classes

class_names = list(val_data_resnet.class_indices.keys())

# %%
#Confusion matrix
cm_resnet101 = confusion_matrix(y_true_resnet101, y_pred_resnet101)

plt.figure(figsize=(6, 5))
sns.heatmap(cm_resnet101, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - ResNet101")
plt.show()

# %% [markdown]
# ## Xception

# %%
#Scaling values using preprocess_input
from tensorflow.keras.applications.xception import Xception, preprocess_input

datagen_preprocessed = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3
)

# Load training data using datagen_preprocessed
train_data_xception = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Load validation data using datagen_preprocessed
val_data_xception = datagen_preprocessed.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 900 images belonging to 3 classes.

# %%
#Loading Xception
base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

#model building
model_xception = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(3, activation='softmax')
])

# %%
#Compilation
model_xception.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#Summary
model_xception.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0012a21e5787> in <cell line: 0>()
# ----> 1 model_xception.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# NameError: name 'model_xception' is not defined

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import time

# Callbacks
checkpoint_xception = ModelCheckpoint(
    'best_model_xception.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_xception = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

early_stopping_xception = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Start training
start_xception = time.time()

history_xception = model_xception.fit(
    train_data_xception,
    epochs=50,
    validation_data=val_data_xception,
    callbacks=[checkpoint_xception, reduce_lr_xception, early_stopping_xception]
)

end_xception = time.time()
runtime_xception = end_xception - start_xception

print(f"Training Time for Xception model: {runtime_xception:.2f} seconds")

# %%
model_xception = load_model("best_model_xception.h5")

# %%
loss_xception, accuracy_xception = model_xception.evaluate(val_data_xception)
print(f"Validation Accuracy: {accuracy_xception:.4f}, Validation Loss: {loss_xception:.4f}")

# %%
#Plots for Xception Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_xception.history['accuracy'], label='Train Accuracy')
plt.plot(history_xception.history['val_accuracy'], label='Val Accuracy')
plt.title('Xception - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_xception.history['loss'], label='Train Loss')
plt.plot(history_xception.history['val_loss'], label='Val Loss')
plt.title('Xception - Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Prediction on validation data
val_pred_xception = model_xception.predict(val_data_preprocessed)
y_pred_xception = np.argmax(val_pred_xception, axis=1)

y_true_xception = val_data_preprocessed.classes

class_names = list(val_data_preprocessed.class_indices.keys())

# %%
#confusion matrix
cm_xception = confusion_matrix(y_true_xception, y_pred_xception)

plt.figure(figsize=(6, 5))
sns.heatmap(cm_xception, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - Xception")
plt.show()

# %% [markdown]
# ## Ensemble Model

# %%
from tensorflow.keras.models import load_model

#Models for ensemble
model_mobilenet = load_model('best_model_mobilenet.h5')
model_efficientnet = load_model('best_model_efficientnet.h5')
model_densenet = load_model('best_model_densenet.h5')
model_resnet101 = load_model('best_model_resnet101.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model_nasnet = load_model('best_model_nasnet.h5')
model_resnet = load_model('best_model_resnet.h5')
model_vgg = load_model('best_vgg_model.h5')
model_xception = load_model('best_model_xception.h5')
model_inception = load_model('best_model_inception.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Pred results from each model
pred_mobilenet = model_mobilenet.predict(val_data_mobilenet, verbose=1)
pred_efficientnet = model_efficientnet.predict(val_data_efficientnet, verbose=1)
pred_densenet = model_densenet.predict(val_data_preprocessed, verbose=1)
pred_resnet = model_resnet.predict(val_data_resnet, verbose=1)
pred_nasnet = model_nasnet.predict(val_data_nasnet, verbose=1)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 446ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 352ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 743ms/step

# %%
pred_resnet101 = model_resnet101.predict(val_data_resnet, verbose=1)
pred_vgg = model_vgg.predict(val_data_vgg, verbose=1)
pred_xception = model_xception.predict(val_data_xception, verbose=1)
pred_inception = model_inception.predict(val_data_inception, verbose=1)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 457ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 23s 367ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 365ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 23s 470ms/step

# %%
true_labels = val_data.classes

# %% [markdown]
# #### Soft Voting (Average)

# %%
from itertools import combinations, product
from sklearn.metrics import accuracy_score, f1_score, classification_report
import numpy as np

#Model predictions
models_pred = {
    'NASNet': pred_nasnet,
    'DenseNet201': pred_densenet,
    'ResNet50': pred_resnet,
    'ResNet101': pred_resnet101,
    'MobileNetV2': pred_mobilenet,
    'EfficientNetB0': pred_efficientnet,
    'VGG16': pred_vgg,
    'Xception': pred_xception,
    'InceptionV3': pred_inception,
}

metrics_info = {
    "accuracy": 0,
    "models": None,
    "weights": None
}

#Different model combinations
for combo in combinations(models_pred.keys(), 3):
    pred_list = [models_pred[m] for m in combo]
    steps = np.arange(0, 1.01, 0.01)

    for weights in product(steps, repeat=3):
        if np.isclose(sum(weights), 1.0):
            combined = sum(w * p for w, p in zip(weights, pred_list))
            preds = np.argmax(combined, axis=1)
            acc = accuracy_score(true_labels, preds)

            if acc > metrics_info["accuracy"]:
                metrics_info["accuracy"] = acc
                metrics_info["models"] = combo
                metrics_info["weights"] = weights

# Final result
print("Best Accuracy from 3-model ensemble:", metrics_info['accuracy'])
print("Best Model Combo:", metrics_info['models'])
print("Best Weights:", metrics_info['weights'])
# Out:
# Best Accuracy from 3-model ensemble: 0.9733333333333334
# Best Model Combo: ('NASNet', 'ResNet50', 'EfficientNetB0')
# Best Weights: (np.float64(0.4), np.float64(0.29), np.float64(0.31))

# %%
avg_pred_weighted = (0.4*pred_nasnet + 0.29*pred_resnet + 0.31*pred_efficientnet) / 3.0
ensemble_prediction_weighted = np.argmax(avg_pred_weighted, axis=1)

# %%
print("Ensemble Accuracy using Soft voting:", accuracy_score(true_labels, ensemble_prediction_weighted))
print("Classification Report:", classification_report(true_labels, ensemble_prediction_weighted))
print("Confusion Matrix:", confusion_matrix(true_labels, ensemble_prediction_weighted))
# Out:
# Ensemble Accuracy using Soft voting: 0.9733333333333334
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       330
#            1       0.96      0.97      0.97       390
#            2       1.00      1.00      1.00       180
#
#     accuracy                           0.97       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.97      0.97      0.97       900
#
# Confusion Matrix: [[316  14   0]
#  [ 10 380   0]
#  [  0   0 180]]

# %%
#Confusion Matrix plot
cm_ensemble = confusion_matrix(true_labels, ensemble_prediction_weighted)

class_names = ['Fresh', 'Mid', 'Rotten']

plt.figure(figsize=(6, 5))
sns.heatmap(cm_ensemble, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Input, Average, Dense, Lambda
import tensorflow as tf

# models for soft voting
nasnet = load_model('best_model_nasnet.h5')
resnet = load_model('best_model_resnet.h5')
efficientnet = load_model('best_model_efficientnet.h5')

nasnet.trainable = False
resnet.trainable = False
efficientnet.trainable = False
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input_shape = (224, 224, 3)
ensemble_input = Input(shape=input_shape)

#predictions
nasnet_output = nasnet(ensemble_input)
resnet_output = resnet(ensemble_input)
efficientnet_output = efficientnet(ensemble_input)

#soft voting with weights
weighted_output = Lambda(lambda x: (0.4 * x[0] + 0.29 * x[1] + 0.31 * x[2]))([nasnet_output, resnet_output, efficientnet_output])

final_output = tf.keras.layers.Softmax()(weighted_output)

# Build and save the model
ensemble_model = Model(inputs=ensemble_input, outputs=final_output)
ensemble_model.save('soft_voting_ensemble.keras')

# %% [markdown]
# #### Hard voting

# %%
from scipy.stats import mode

stacked_pred = np.stack([
    np.argmax(pred_nasnet, axis=1),
    np.argmax(pred_efficientnet, axis=1),
    np.argmax(pred_resnet, axis=1)], axis=1)

hard_vote_pred, count = mode(stacked_pred, axis=1) #mode, count
final_preds = hard_vote_pred.flatten()

# %%
print("Ensemble Accuracy using Hard Voting:", accuracy_score(true_labels, final_preds))
print("Classification Report:", classification_report(true_labels, final_preds))
print("Confusion Matrix:", confusion_matrix(true_labels, final_preds))
# Out:
# Ensemble Accuracy using Hard Voting: 0.9722222222222222
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       330
#            1       0.96      0.97      0.97       390
#            2       1.00      0.99      1.00       180
#
#     accuracy                           0.97       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.97      0.97      0.97       900
#
# Confusion Matrix: [[316  14   0]
#  [ 10 380   0]
#  [  0   1 179]]

# %% [markdown]
# ##  Feature-Level Model Ensemble

# %% [markdown]
# #### VGG16 + ResNet50 + MobileNetV2

# %%
def rename_model(model, prefix, input_shape=(224, 224, 3)):
    # Freeze original model
    model.trainable = True

    # Create new input
    new_input = Input(shape=input_shape, name=f'{prefix}_input')

    # Apply model to the new input
    new_output = model(new_input)

    # Create a new model with renamed scope
    new_model = Model(inputs=new_input, outputs=new_output, name=f'{prefix}_model')

    return new_model

# Load and wrap each model
vgg = rename_model(load_model('best_vgg_model.h5', compile=False), 'vgg')
resnet = rename_model(load_model('best_model_resnet.h5', compile=False), 'resnet')
mobilenet = rename_model(load_model('best_model_mobilenet.h5', compile=False), 'mobilenet')

# common input
commonInput = Input((224, 224, 3), name="ensemble_input")
out1 = vgg(commonInput)
out2 = resnet(commonInput)
out3 = mobilenet(commonInput)

# Merged outputs
merged = Add(name='merge_outputs')([out1, out2, out3])

# ensemble model
newModel = Model(inputs=commonInput, outputs=merged, name='ensemble_model')

# %%
# Compilation
newModel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
newModel.summary()
# Out:
# Model: "ensemble_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ensemble_input      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg_model           │ (None, 3)         │ 14,846,787 │ ensemble_input[0… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet_model        │ (None, 3)         │ 24,113,027 │ ensemble_input[0… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenet_model     │ (None, 3)         │  2,586,691 │ ensemble_input[0… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_outputs (Add) │ (None, 3)         │          0 │ vgg_model[0][0],  │
# │                     │                   │            │ resnet_model[0][… │
# │                     │                   │            │ mobilenet_model[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 41,546,505 (158.49 MB)
#  Trainable params: 986,121 (3.76 MB)
#  Non-trainable params: 40,560,384 (154.73 MB)

# %%
checkpoint_ensemble = ModelCheckpoint(
    'model_ensemble.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

start_ensemble = time.time()

history_ensemble = newModel.fit(
    train_data_mobilenet,
    epochs=50,
    validation_data=val_data_mobilenet,
    callbacks=[checkpoint_ensemble]
)

end_ensemble = time.time()
runtime_ensemble = end_ensemble - start_ensemble

print(f"Training Time for Ensemble model: {runtime_ensemble:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.8157 - loss: 0.5316
# Epoch 1: val_accuracy improved from -inf to 0.90667, saving model to model_ensemble.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 79s 884ms/step - accuracy: 0.8164 - loss: 0.5308 - val_accuracy: 0.9067 - val_loss: 0.3738
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9162 - loss: 0.3499
# Epoch 2: val_accuracy improved from 0.90667 to 0.92556, saving model to model_ensemble.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 43s 429ms/step - accuracy: 0.9163 - loss: 0.3496 - val_accuracy: 0.9256 - val_loss: 0.2884
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9226 - loss: 0.2801
# Epoch 3: val_accuracy did not improve from 0.92556
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 397ms/step - accuracy: 0.9227 - loss: 0.2800 - val_accuracy: 0.9222 - val_loss: 0.2701
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9275 - loss: 0.2639
# Epoch 4: val_accuracy improved from 0.92556 to 0.93222, saving model to model_ensemble.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 42s 415ms/step - accuracy: 0.9275 - loss: 0.2637 - val_accuracy: 0.9322 - val_loss: 0.2394
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9360 - loss: 0.2339
# Epoch 5: val_accuracy improved from 0.93222 to 0.93444, saving model to model_ensemble.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 31s 451ms/step - accuracy: 0.9360 - loss: 0.2339 - val_accuracy: 0.9344 - val_loss: 0.2394
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9348 - loss: 0.2331
# Epoch 6: val_accuracy did not improve from 0.93444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 396ms/step - accuracy: 0.9349 - loss: 0.2329 - val_accuracy: 0.9311 - val_loss: 0.2148
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9510 - loss: 0.2067
# Epoch 7: val_accuracy improved from 0.93444 to 0.94556, saving model to model_ensemble.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 419ms/step - accuracy: 0.9509 - loss: 0.2068 - val_accuracy: 0.9456 - val_loss: 0.2204
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9464 - loss: 0.1944
# Epoch 8: val_accuracy improved from 0.94556 to 0.95444, saving model to model_ensemble.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 416ms/step - accuracy: 0.9464 - loss: 0.1945 - val_accuracy: 0.9544 - val_loss: 0.2260
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9516 - loss: 0.1926
# Epoch 9: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 402ms/step - accuracy: 0.9515 - loss: 0.1927 - val_accuracy: 0.9389 - val_loss: 0.2247
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9419 - loss: 0.1914
# Epoch 10: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 398ms/step - accuracy: 0.9419 - loss: 0.1915 - val_accuracy: 0.9422 - val_loss: 0.2407
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9498 - loss: 0.1846
# Epoch 11: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 395ms/step - accuracy: 0.9498 - loss: 0.1846 - val_accuracy: 0.9511 - val_loss: 0.1898
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9534 - loss: 0.2031
# Epoch 12: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 396ms/step - accuracy: 0.9535 - loss: 0.2029 - val_accuracy: 0.9400 - val_loss: 0.1999
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9572 - loss: 0.1884
# Epoch 13: val_accuracy did not improve from 0.95444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 394ms/step - accuracy: 0.9571 - loss: 0.1884 - val_accuracy: 0.9411 - val_loss: 0.2199
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.
accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_ensemble.history['accuracy'], label='Train Accuracy')
plt.plot(history_ensemble.history['val_accuracy'], label='Val Accuracy')
plt.title('(VGG16 + ResNet50 + MobileNetV2)- Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_ensemble.history['loss'], label='Train Loss')
plt.plot(history_ensemble.history['val_loss'], label='Val Loss')
plt.title('(VGG16 + ResNet50 + MobileNetV2)- Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Confusion matrix
#Prediction on validation data
val_pred_ensemble = ensemble_concatenate.predict(val_data_mobilenet)
y_pred_ensemble = np.argmax(val_pred_ensemble , axis=1)

y_true_ensemble  = val_data_mobilenet.classes

class_names = list(val_data_mobilenet.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 512ms/step

# %%
cm_ensemble = confusion_matrix(y_true_ensemble , y_pred_ensemble)
#show cm
plt.figure(figsize=(6, 5))
sns.heatmap(cm_ensemble, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Ensemble (VGG16 + ResNet50 + MobileNetV2)')
plt.show()

# %% [markdown]
# #### NASNetMobile + ResNet50 + EfficientNetB0

# %%
def rename_model(model, prefix, input_shape=(224, 224, 3)):
    # Freeze original model
    model.trainable = True

    # Create new input
    new_input = Input(shape=input_shape, name=f'{prefix}_input')

    # Apply model to the new input
    new_output = model(new_input)

    # Create a new model with renamed scope
    new_model = Model(inputs=new_input, outputs=new_output, name=f'{prefix}_model')

    return new_model

# %%
# Load and wrap each model
efficientnet = rename_model(load_model('best_model_efficientnet.h5', compile=False), 'efficientnet')
resnet = rename_model(load_model('best_model_resnet.h5', compile=False), 'resnet')
nasnet = rename_model(load_model('best_model_nasnet.h5', compile=False), 'nasnet')

# common input
commonInput = Input((224, 224, 3), name="ensemble_input")
out1 = efficientnet(commonInput)
out2 = resnet(commonInput)
out3 = nasnet(commonInput)

# Merged outputs
merged = Add(name='merge_outputs')([out1, out2, out3])

# ensemble model
newModel2 = Model(inputs=commonInput, outputs=merged, name='ensemble_model')

# %%
# Compilation
newModel2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
newModel2.summary()
# Out:
# Model: "ensemble_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ensemble_input      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnet_model  │ (None, 3)         │  4,378,278 │ ensemble_input[0… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet_model        │ (None, 3)         │ 24,113,027 │ ensemble_input[0… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ nasnet_model        │ (None, 3)         │  4,541,079 │ ensemble_input[0… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_outputs (Add) │ (None, 3)         │          0 │ efficientnet_mod… │
# │                     │                   │            │ resnet_model[0][… │
# │                     │                   │            │ nasnet_model[0][… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 33,032,384 (126.01 MB)
#  Trainable params: 1,125,385 (4.29 MB)
#  Non-trainable params: 31,906,999 (121.72 MB)

# %%
checkpoint_ensemble2 = ModelCheckpoint(
    'model_ensemble2.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

start_ensemble2 = time.time()

history_ensemble2 = newModel2.fit(
    train_data_efficientnet,
    epochs=50,
    validation_data=val_data_efficientnet,
    callbacks=[checkpoint_ensemble2]
)

end_ensemble2 = time.time()
runtime_ensemble2 = end_ensemble2 - start_ensemble2

print(f"Training Time for Ensemble model 2: {runtime_ensemble2:.2f} seconds")
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.9282 - loss: 0.4557
# Epoch 1: val_accuracy improved from -inf to 0.96000, saving model to model_ensemble2.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━
val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 407ms/step - accuracy: 0.9652 - loss: 0.3781 - val_accuracy: 0.9600 - val_loss: 0.3935
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9668 - loss: 0.3863
# Epoch 42: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 26s 400ms/step - accuracy: 0.9667 - loss: 0.3862 - val_accuracy: 0.9622 - val_loss: 0.3818
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9687 - loss: 0.3708
# Epoch 43: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 24s 364ms/step - accuracy: 0.9687 - loss: 0.3709 - val_accuracy: 0.9578 - val_loss: 0.4046
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9691 - loss: 0.3803
# Epoch 44: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 23s 350ms/step - accuracy: 0.9691 - loss: 0.3803 - val_accuracy: 0.9622 - val_loss: 0.3908
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9705 - loss: 0.3660
# Epoch 45: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 24s 366ms/step - accuracy: 0.9706 - loss: 0.3661 - val_accuracy: 0.9611 - val_loss: 0.3936
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9731 - loss: 0.3765
# Epoch 46: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 23s 356ms/step - accuracy: 0.9730 - loss: 0.3765 - val_accuracy: 0.9611 - val_loss: 0.3907
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9671 - loss: 0.3835
# Epoch 47: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 24s 362ms/step - accuracy: 0.9671 - loss: 0.3834 - val_accuracy: 0.9611 - val_loss: 0.3833
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9689 - loss: 0.3711
# Epoch 48: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 410ms/step - accuracy: 0.9689 - loss: 0.3712 - val_accuracy: 0.9633 - val_loss: 0.3986
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9579 - loss: 0.3792
# Epoch 49: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 372ms/step - accuracy: 0.9579 - loss: 0.3792 - val_accuracy: 0.9633 - val_loss: 0.3998
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9647 - loss: 0.3707
# Epoch 50: val_accuracy did not improve from 0.96444
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 406ms/step - accuracy: 0.9647 - loss: 0.3707 - val_accuracy: 0.9622 - val_loss: 0.3764
# Training Time for Ensemble model 2: 1557.98 seconds

# %%
ensemble_model2 = load_model('model_ensemble2.keras')

# %%
loss_ensemble2, accuracy_ensemble2 = ensemble_model2.evaluate(val_data_efficientnet)
print(f"Validation Accuracy: {accuracy_ensemble2:.4f}, Validation Loss: {loss_ensemble2:.4f}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 49s 691ms/step - accuracy: 0.9444 - loss: 0.5979
# Validation Accuracy: 0.9600, Validation Loss: 0.4783

# %%
#Plots for Ensemble model 2 Accuracy and loss
plt.figure(figsize=(10, 5))

#Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_ensemble2.history['accuracy'], label='Train Accuracy')
plt.plot(history_ensemble2.history['val_accuracy'], label='Val Accuracy')
plt.title('NASNetMobile + ResNet50 + EfficientNetB0) - Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

#Loss
plt.subplot(1, 2, 2)
plt.plot(history_ensemble2.history['loss'], label='Train Loss')
plt.plot(history_ensemble2.history['val_loss'], label='Val Loss')
plt.title('(NASNetMobile + ResNet50 + EfficientNetB0)- Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Confusion matrix
#Prediction on validation data
val_pred_ensemble2 = ensemble_model2.predict(val_data_efficientnet)
y_pred_ensemble2 = np.argmax(val_pred_ensemble2, axis=1)

y_true_ensemble2  = val_data_efficientnet.classes

class_names = list(val_data_efficientnet.class_indices.keys())
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step

# %%
cm_ensemble2 = confusion_matrix(y_true_ensemble2 , y_pred_ensemble2)
#show cm
plt.figure(figsize=(6, 5))
sns.heatmap(cm_ensemble2, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Ensemble (NASNetMobile + ResNet50 + EfficientNetB0)')
plt.show()
